# %% [markdown]
# # Property Price Estimator

# %% [markdown]
# ## Library imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load data

# %%
df_retail = pd.read_excel('../data/properties_retail.xlsx')
df_resell = pd.read_excel('../data/properties_resell.xlsx')

# %%
# Adding new binary variable to distinguish between retail and resell markets
df_retail['market'] = 0
df_resell['market'] = 1

# %%
df = pd.concat([df_retail, df_resell], ignore_index=True)

# %%
# Set float display format to plain decimal
pd.set_option('display.float_format', '{:.2f}'.format)

# %% [markdown]
# ## Clean data

# %%
df.isna().sum()
# Out:
# url                     0
# title                   0
# price                1163
# surface                 1
# rooms                  49
# floor                  75
# construction_year     295
# material             1049
# latitude                3
# longitude               3
# location                0
# id                    742
# heating              8086
# sewage               8045
# market                  0
# dtype: int64

# %%
# Target Variable creation
df['price_per_square_meter'] = df['price'] / df['surface']

# %%
# Drop unnecessary columns and the columns that create target variable
df = df.drop(columns=['id', 'url', 'title', 'location', 'sewage', 'heating', 'price'])
# I was not sure if 'surface' should be dropped as well, but I decided to keep it as it could be useful for further analysis and modeling.
# I was concerned that it might create a data leakage, but surface is aways available and it is not derived from price, so I believe it should be fine to keep it.

# %%
# Drop rows with missing critical features (except price)
df = df.dropna(subset=['rooms', 'floor','construction_year', 'latitude', 'longitude'])

# %%
# Fill remaining missing values with 'inny'
df['material'] = df['material'].fillna('inny')

# %%
df.isna().sum()
# Out:
# surface                      1
# rooms                        0
# floor                        0
# construction_year            0
# material                     0
# latitude                     0
# longitude                    0
# market                       0
# price_per_square_meter    1160
# dtype: int64

# %%
# Convert data types
numeric_columns = {
    'price_per_square_meter': 'float',
    'surface': 'float',
    'rooms': 'Int64',
    'floor': 'Int64',
    'construction_year': 'Int64',
    'latitude': 'float',
    'longitude': 'float',
    'market': 'Int64'
}
df = df.astype(numeric_columns)

# %%
df.dtypes
# Out:
# surface                   float64
# rooms                       Int64
# floor                       Int64
# construction_year           Int64
# material                   object
# latitude                  float64
# longitude                 float64
# market                      Int64
# price_per_square_meter    float64
# dtype: object

# %%
df
# Out:
#       surface  rooms  floor  construction_year      material  latitude  \
# 0       38.30      2      0               2027          inny     52.32
# 1       40.37      2      3               2025          inny     52.18
# 2       29.52      1      1               2025         beton     52.23
# 3       53.27      3      4               2026         beton     52.29
# 4       28.89      1      2               2026          inny     52.25
# ...       ...    ...    ...                ...           ...       ...
# 9148    47.10      2      0               2000         cegła     52.32
# 9149    84.10      4      4               1980  wielka płyta     52.16
# 9150    29.50      2      4               1968         cegła     52.22
# 9151    68.00      3      7               1993          inny     52.24
# 9152    57.33      3      1               1906          inny     52.24
#
#       longitude  market  price_per_square_meter
# 0         21.05       0                12990.00
# 1         20.94       0                17215.75
# 2         21.11       0                20447.15
# 3         21.02       0                     NaN
# 4         21.08       0                18033.92
# ...         ...     ...                     ...
# 9148      20.96       1                13375.80
# 9149      21.03       1                11296.08
# 9150      21.23       1                21694.92
# 9151      20.92       1                14661.76
# 9152      20.99       1                27385.31
#
# [8767 rows x 9 columns]

# %% [markdown]
# # Saving dataframe

# %%
df.to_excel('../data/properties_sampled.xlsx', index=False)
